# %% [markdown]
# # **Homework 2**
# ## **Author: Jake Brulato**

# %% [markdown]
# **Import the Packages**

# %%
import pandas as pd
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snspi

# %% [markdown]
# **Read the data**

# %%
data = pd.read_table('Nichols_Nicki.dat')
data
# Out:
#      ias1  ias2  ias3  ias4  ias5  ias6  ias7  ias8  ias9  ias10  ...  ias27  \
# 0       1     1     2     1     1     1     1     2     2      1  ...      3
# 1       2     1     3     1     2     1     1     2     1      1  ...      3
# 2       4     2     4     2     3     3     4     2     3      3  ...      3
# 3       1     1     3     1     1     1     1     2     1      1  ...      1
# 4       2     1     3     2     1     1     1     2     3      1  ...      3
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...    ...
# 202     1     1     3     2     2     1     1     2     1      1  ...      3
# 203     1     1     4     1     1     1     1     3     1      1  ...      2
# 204     3     2     4     3     2     3     2     4     4      2  ...      2
# 205     3     1     5     1     1     3     4     3     2      2  ...      4
# 206     1     1     1     1     2     1     3     4     4      3  ...      2
#
# ...

# %% [markdown]
# **Successfully remove the two variables with low variances**

# %%
stats = data.describe().T.sort_values("std").head()
print(stats)
# Out:
#        count      mean       std  min  25%  50%  75%  max
# ias34  207.0  1.111111  0.344474  1.0  1.0  1.0  1.0  3.0
# ias23  207.0  1.144928  0.427525  1.0  1.0  1.0  1.0  3.0
# ias15  207.0  1.231884  0.516098  1.0  1.0  1.0  1.0  3.0
# ias28  207.0  1.236715  0.563454  1.0  1.0  1.0  1.0  4.0
# ias6   207.0  1.222222  0.565075  1.0  1.0  1.0  1.0  4.0

# %% [markdown]
# **Alternative way to remove the two variables with low variances**

# %%
variances = data.var()
lowest_variance_items = variances.nsmallest(2).index.tolist()
print("Items dropped for low variances:", lowest_variance_items)
var_drop = data.drop(['ias34','ias23'], axis= 1)
var_drop
# Out:
# Items dropped for low variances: ['ias34', 'ias23']
#      ias1  ias2  ias3  ias4  ias5  ias6  ias7  ias8  ias9  ias10  ...  ias26  \
# 0       1     1     2     1     1     1     1     2     2      1  ...      1
# 1       2     1     3     1     2     1     1     2     1      1  ...      1
# 2       4     2     4     2     3     3     4     2     3      3  ...      3
# 3       1     1     3     1     1     1     1     2     1      1  ...      1
# 4       2     1     3     2     1     1     1     2     3      1  ...      1
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...    ...
# 202     1     1     3     2     2     1     1     2     1      1  ...      1
# 203     1     1     4     1     1     1     1     3     1      1  ...      1
# 204     3     2     4     3     2     3     2     4     4      2  ...      3
# 205     3     1     5     1     1     3     4     3     2      2  ...      2
# ...

# %%
var_drop.corr()
# Out:
#            ias1      ias2      ias3      ias4      ias5      ias6      ias7  \
# ias1   1.000000  0.427736  0.462768  0.354683  0.517041  0.558645  0.478892
# ias2   0.427736  1.000000  0.330520  0.541461  0.379329  0.239192  0.394668
# ias3   0.462768  0.330520  1.000000  0.518899  0.474619  0.405834  0.485200
# ias4   0.354683  0.541461  0.518899  1.000000  0.462147  0.266996  0.451263
# ias5   0.517041  0.379329  0.474619  0.462147  1.000000  0.481312  0.429718
# ias6   0.558645  0.239192  0.405834  0.266996  0.481312  1.000000  0.497405
# ias7   0.478892  0.394668  0.485200  0.451263  0.429718  0.497405  1.000000
# ias8   0.476363  0.316346  0.624529  0.444075  0.588049  0.433835  0.465954
# ias9   0.512624  0.285332  0.500271  0.369303  0.508687  0.499149  0.541858
# ias10  0.431542  0.295806  0.401046  0.370661  0.520405  0.587692  0.601882
# ias11  0.418803  0.260113  0.428615  0.266908  0.336068  0.420593  0.407984
# ...

# %% [markdown]
# **Look at the confusion matrix and remove the three variables with low correlations**

# %%
corr = var_drop.corr()

# # # If you want to see the matrix in a csv, uncomment below
# conf_df = pd.DataFrame(corr)
# conf_df.to_csv('confusion_matrix.csv', index=True, header=False)

f_data = var_drop.drop(['ias13', 'ias22', 'ias32'], axis=1)
f_data.corr()
# Out:
#            ias1      ias2      ias3      ias4      ias5      ias6      ias7  \
# ias1   1.000000  0.427736  0.462768  0.354683  0.517041  0.558645  0.478892
# ias2   0.427736  1.000000  0.330520  0.541461  0.379329  0.239192  0.394668
# ias3   0.462768  0.330520  1.000000  0.518899  0.474619  0.405834  0.485200
# ias4   0.354683  0.541461  0.518899  1.000000  0.462147  0.266996  0.451263
# ias5   0.517041  0.379329  0.474619  0.462147  1.000000  0.481312  0.429718
# ias6   0.558645  0.239192  0.405834  0.266996  0.481312  1.000000  0.497405
# ias7   0.478892  0.394668  0.485200  0.451263  0.429718  0.497405  1.000000
# ias8   0.476363  0.316346  0.624529  0.444075  0.588049  0.433835  0.465954
# ias9   0.512624  0.285332  0.500271  0.369303  0.508687  0.499149  0.541858
# ias10  0.431542  0.295806  0.401046  0.370661  0.520405  0.587692  0.601882
# ias11  0.418803  0.260113  0.428615  0.266908  0.336068  0.420593  0.407984
# ...

# %% [markdown]
# **Correct the eigenvalues**

# %%
#Calculating the eigen value
# f_cor = f_data.corr()
cov_mat = np.cov(f_data.T)
#np.cov(f_data)

eigen_vals, eigen_vecs = np.linalg.eig(cov_mat)
eigen_vals
# Out:
# array([9.39125543, 1.24515555, 1.10299324, 0.95304005, 0.77301975,
#        0.63877591, 0.57708496, 0.53989026, 0.46848507, 0.44204512,
#        0.41070427, 0.37201006, 0.36019535, 0.0453143 , 0.05559301,
#        0.06549541, 0.32573639, 0.08833419, 0.10109319, 0.30962996,
#        0.12344991, 0.13704314, 0.28016405, 0.16390667, 0.16615511,
#        0.18382076, 0.19611993, 0.25722439, 0.24472739, 0.22869559,
#        0.23002373])

# %% [markdown]
# **PCA with all n_components**

# %%
pca = PCA(n_components=None)
f_data_pca = pca.fit_transform(f_data)
pca.explained_variance_ratio_
# Out:
# array([0.4586205 , 0.06080698, 0.0538645 , 0.04654156, 0.0377503 ,
#        0.03119452, 0.02818185, 0.02636546, 0.0228784 , 0.0215872 ,
#        0.02005668, 0.01816705, 0.01759008, 0.01590729, 0.01512073,
#        0.01368177, 0.01256151, 0.01195122, 0.01123317, 0.01116831,
#        0.00957749, 0.00897686, 0.00811416, 0.00800436, 0.00669248,
#        0.00602866, 0.00493687, 0.00431379, 0.00319846, 0.00271488,
#        0.00221292])

# %% [markdown]
# **PCA with 5 n_components**

# %%
pca_5 = PCA(n_components=5)
f_data_pca2 = pca_5.fit_transform(f_data)
pca_5.explained_variance_ratio_
# Out:
# array([0.4586205 , 0.06080698, 0.0538645 , 0.04654156, 0.0377503 ])
